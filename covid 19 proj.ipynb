# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('us_covid19_daily.csv')

# %%
data
# Out:
#          date  states  positive   negative  pending  hospitalizedCurrently  \
# 0    20201206      56  14534035  161986294  13592.0               101487.0
# 1    20201205      56  14357264  160813704  13433.0               101190.0
# 2    20201204      56  14146191  159286709  12714.0               101276.0
# 3    20201203      56  13921360  158026052  15106.0               100755.0
# 4    20201202      56  13711156  156787587  14368.0               100322.0
# ..        ...     ...       ...        ...      ...                    ...
# 315  20200126       2         0          0      NaN                    NaN
# 316  20200125       2         0          0      NaN                    NaN
# 317  20200124       2         0          0      NaN                    NaN
# 318  20200123       2         0          0      NaN                    NaN
# 319  20200122       2         0          0      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'totalTestResults',
#        'lastModified', 'total', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')

# %%
data.tail()
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 315  20200126       2         0         0      NaN                    NaN
# 316  20200125       2         0         0      NaN                    NaN
# 317  20200124       2         0         0      NaN                    NaN
# 318  20200123       2         0         0      NaN                    NaN
# 319  20200122       2         0         0      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 315                     NaN             NaN              NaN
# 316                     NaN             NaN              NaN
# 317                     NaN             NaN              NaN
# 318                     NaN             NaN              NaN
# 319                     NaN             NaN              NaN
#
#      onVentilatorCurrently  ...  totalTestResults          lastModified total  \
# ...

# %%
data.describe()
# Out:
#                date      states      positive      negative       pending  \
# count  3.200000e+02  320.000000  3.200000e+02  3.200000e+02    278.000000
# mean   2.020066e+07   48.853125  3.963366e+06  4.707150e+07   9042.223022
# std    3.041616e+02   17.519724  3.837424e+06  4.863156e+07  11367.578741
# min    2.020012e+07    2.000000  0.000000e+00  0.000000e+00    124.000000
# 25%    2.020041e+07   56.000000  5.243978e+05  2.177519e+06   2819.500000
# 50%    2.020063e+07   56.000000  2.600174e+06  2.954071e+07   4300.000000
# 75%    2.020092e+07   56.000000  6.624805e+06  8.293463e+07  11444.250000
# max    2.020121e+07   56.000000  1.453404e+07  1.619863e+08  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count             265.000000              278.000000      256.000000
# mean            44522.373585           276808.104317     9200.675781
# std             19060.814409           160875.737479     3806.564610
# ...

# %%
data.isnull().sum()
# Out:
# date                         0
# states                       0
# positive                     0
# negative                     0
# pending                     42
# hospitalizedCurrently       55
# hospitalizedCumulative      42
# inIcuCurrently              64
# inIcuCumulative             63
# onVentilatorCurrently       63
# onVentilatorCumulative      70
# recovered                   63
# dateChecked                  0
# death                       19
# hospitalized                42
# totalTestResults             0
# lastModified                 0
# total                        0
# posNeg                       0
# deathIncrease                0
# hospitalizedIncrease         0
# negativeIncrease             0
# positiveIncrease             0
# totalTestResultsIncrease     0
# hash                         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'totalTestResults',
#        'lastModified', 'total', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')

# %% [markdown]
# # scatter plots

# %%
sns.relplot(x="positive", y="recovered", data = data)

# %%
sns.relplot(x="positive", y="death", data = data)

# %%
sns.relplot(x="positive", y="hospitalizedCurrently", data = data)

# %%
sns.relplot(x="negative", y="death", data = data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'totalTestResults',
#        'lastModified', 'total', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')

# %%
sns.relplot(x='positive', y='hospitalizedCumulative', kind='line', data=data)

# %%
sns.relplot(x='onVentilatorCumulative', y='hospitalizedCumulative', kind='line', data=data)

# %%
sns.relplot(x='onVentilatorCumulative', y='death', kind='line', data=data)

# %%
sns.relplot(x='onVentilatorCumulative', y='recovered', kind='line', data=data)

# %%
sns.catplot(x='onVentilatorCumulative', y='recovered', data=data)
